# %% [markdown]
# <a href="https://colab.research.google.com/github/akashakash9931/data-science/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,20,100)
y=np.sin(x)

plt.plot(x,y,label="Sine Wave")

plt.xlabel("x Axis")
plt.ylabel("y Axis")

plt.title("Product Name")

plt.legend()
plt.show()

# %%
Categories = ['A','B','C','D']
Values = [10,25,15,30]

plt.figure(figsize=(6,4))

plt.bar('categories','values',color='Purple')

plt.xlabel("Categories")
plt.ylabel("Values")

plt.title("Bar Chart Example")

plt.show()

# %%
data = np.random.randn(1000)
plt.figure(figsize=(7, 5))
plt.hist(data, bins=30, color='green', edgecolor='black', alpha=0.7)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram Example")
plt.show()

# %%
import seaborn as sns
import pandas as pd
# Creating sample data
data = np.random.randn(1000)
df = pd.DataFrame(data, columns=['Values'])
# Plot
sns.histplot(df['Values'], bins=30, kde=True, color='blue')
plt.title("Histogram with KDE")
plt.show()

# %%
tips = sns.load_dataset('tips')
plt.figure(figsize=(6, 4))
sns.boxplot(x=tips['total_bill'])
plt.title("Box Plot of Total Bill")
plt.show()

# %%
sns.pairplot(tips, hue='sex')
plt.show()

# %%
corr_matrix = tips.select_dtypes(include=np.number).corr()

plt.figure(figsize=(7, 5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

plt.figure(figsize=(7,5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
